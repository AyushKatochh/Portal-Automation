# %%
import json
from bson import ObjectId
from pymongo import MongoClient
MONGO_URI = 'mongodb+srv://AyushKatoch:ayush2002@cluster0.72gtk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
client = MongoClient(MONGO_URI)
db = client['aicte']
documents=db["docresults"]


data=list(documents.find())
# Application ID to search for
search_application_id = ObjectId('675245d40df0c2662c2f40eb')

# Parse the JSON to find the matching application_id
matching_document = next((doc for doc in data if doc['application_id'] == search_application_id), None)

# Print the result
if matching_document:
    print(json.dumps(matching_document, indent=4, default=str))
else:
    print("No document found with the specified application_id.")
# Out:
# {
#     "_id": "6752507401880481f7eff9b6",
#     "application_id": "675245d40df0c2662c2f40eb",
#     "result": {
#         "document_type": "land_conversion_certificate",
#         "combined_result": {
#             "document_type": "land_conversion_certificate",
#             "ocr_extraction": {
#                 "document_name": null,
#                 "certificate_number": "Memo.No. G& 9S /L.M./SDL & LRO/AsL/16",
#                 "issuing_authority": "Office of the Sub-Divisional Land and Land Reforms Officer, Asansol, Dist. Burdwan",
#                 "issue_date": "30/06/2016",
#                 "applicant_name": "M/S- Hira Panna Constructions(P) Ltd.",
#                 "contact_information": "River Side Road, near Neheru Park, P.O. Burnpur,P.S. Hirapur, Dist. Burdwan",
#                 "location": "Hirapur",
#                 "area_of_land": "0.05Acres"
#             },
#             "signatures": [
#                 {
#                     "type": "signature",
# ...

# %%
logs=db["logs"]

data=list(logs.find())

# Application ID to search for
search_application_id = ObjectId('675245d40df0c2662c2f40eb')

# Parse the JSON to find the matching application_id
matching_document = next((doc for doc in data if doc['application_id'] == search_application_id), None)

# Print the result
if matching_document:
    print(json.dumps(matching_document, indent=4, default=str))
else:
    print("No document found with the specified application_id.")
# Out:
# {
#     "_id": "67525e52e84e6dd3c8167169",
#     "application_id": "675245d40df0c2662c2f40eb",
#     "status": "In Progress",
#     "stage": {
#         "document_verification": {
#             "is_completed": true,
#             "success": true,
#             "verification_timestamp": "2024-12-06 14:08:13.066000",
#             "remark": "all the document is validated",
#             "is_allocated": false
#         },
#         "expert_visit_stage": {
#             "is_completed": true,
#             "success": true,
#             "verification_timestamp": "2024-12-06 16:57:06.892000",
#             "remark": "Dimensions of the university is verified"
#         },
#         "final_stage": {
#             "is_allocated": true,
#             "deadline": "2024-12-09 16:57:06.798000"
#         }
#     },
#     "status_logs": [
#         {
#             "message": "Allocated a scrutiny member for document verification.",
#             "_id": "67525e52e84e6dd3c816716a",
# ...
